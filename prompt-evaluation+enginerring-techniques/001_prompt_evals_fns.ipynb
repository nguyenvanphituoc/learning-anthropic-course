# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task",
        "format": "json" or "python" or "regex"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.333333333333334

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\nimport sys\n\npattern = r'i-[0-9a-f]{17}'\n\nfor line in sys.stdin:\n    matches = re.findall(pattern, line)\n    for match in matches:\n        print(match)\n",
#     "test_case": {
#       "task": "Extract all AWS EC2 instance IDs from a CloudWatch log file where instance IDs follow the pattern 'i-' followed by 17 hexadecimal characters",
#       "format": "regex"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly implements the core requirement with an appropriate regex pattern and clean logic. However, it has a critical flaw: AWS EC2 instance IDs can contain uppercase hexadecimal characters, but the pattern only matches lowercase (0-9a-f). The corrected pattern should be either r'i-[0-9a-fA-F]{17}' or r'i-[0-9a-f]{17}' with re.IGNORECASE flag. The code is otherwise functional and follows good practices for log file processing."
#   },
#   {
#     "output": "\nimport json\nimport re\nfrom typing import List\n\ndef extract_s3_getobject_principals(policy_json: str) -> List[str]:\n    \"\"\"Extract all Principal ARNs that have s3:GetObject action from an S3 bucket policy.\"\"\"\n    try:\n        policy = json.loads(policy_json)\n    except json.JSONDecodeError:\n        return []\n    \n    principals = []\n    statements = policy.get('Statement', [])\n    \n    for statement in statements:\n        actions = statement.get('Action', [])\n        if isinstance(actions, str):\n            actions = [actions]\n        \n        has_get_object = any(\n            action == 's3:GetObject' or action == '*' or action.endswith(':*')\n            for action in actions\n        )\n        \n        if not has_get_object:\n            continue\n        \n        principal = statement.get('Principal')\n        if principal:\n            if isinstance(principal, str):\n                principals.append(principal)\n            elif isinstance(principal, dict):\n                for key, value in principal.items():\n                    if isinstance(value, str):\n                        principals.append(value)\n                    elif isinstance(value, list):\n                        principals.extend(value)\n    \n    return principals\n\n\nif __name__ == \"__main__\":\n    sample_policy = \"\"\"{\n        \"Version\": \"2012-10-17\",\n        \"Statement\": [\n            {\n                \"Effect\": \"Allow\",\n                \"Principal\": {\n                    \"AWS\": \"arn:aws:iam::123456789012:user/example\"\n                },\n                \"Action\": \"s3:GetObject\",\n                \"Resource\": \"arn:aws:s3:::bucket/*\"\n            },\n            {\n                \"Effect\": \"Allow\",\n                \"Principal\": \"*\",\n                \"Action\": [\"s3:GetObject\", \"s3:PutObject\"],\n                \"Resource\": \"arn:aws:s3:::bucket/*\"\n            }\n        ]\n    }\"\"\"\n    \n    result = extract_s3_getobject_principals(sample_policy)\n    print(json.dumps(result, indent=2))\n",
#     "test_case": {
#       "task": "Parse an AWS S3 bucket policy JSON and extract all Principal ARNs that have the 's3:GetObject' action",
#       "format": "python"
#     },
#     "score": 8.0,
#     "reasoning": "The solution correctly parses the JSON structure and handles the core requirement of extracting principals with s3:GetObject actions. However, it has a critical flaw: it ignores the Effect field, so it would incorrectly include principals from Deny statements. In AWS policies, a principal in a Deny statement should not be treated the same as one in an Allow statement. The wildcard principal '*' is also extracted as-is without special handling, though this may be intentional. The code is otherwise well-structured and handles most common formats of principals and actions appropriately."
#   },
#   {
#     "output": "\n{\n  \"AWSTemplateFormatVersion\": \"2010-09-09\",\n  \"Resources\": {\n    \"LambdaExecutionRole\": {\n      \"Type\": \"AWS::IAM::Role\",\n      \"Properties\": {\n        \"AssumeRolePolicyDocument\": {\n          \"Version\": \"2012-10-17\",\n          \"Statement\": [\n            {\n              \"Effect\": \"Allow\",\n              \"Principal\": {\n                \"Service\": \"lambda.amazonaws.com\"\n              },\n              \"Action\": \"sts:AssumeRole\"\n            }\n          ]\n        },\n        \"ManagedPolicyArns\": [\n          \"arn:aws:iam::aws:policy/service-role/AWSLambdaBasicExecutionRole\"\n        ]\n      }\n    },\n    \"HelloWorldFunction\": {\n      \"Type\": \"AWS::Lambda::Function\",\n      \"Properties\": {\n        \"FunctionName\": \"HelloWorldFunction\",\n        \"Runtime\": \"python3.11\",\n        \"Role\": {\n          \"Fn::GetAtt\": [\n            \"LambdaExecutionRole\",\n            \"Arn\"\n          ]\n        },\n        \"Handler\": \"index.lambda_handler\",\n        \"Code\": {\n          \"ZipFile\": \"def lambda_handler(event, context):\\n    return {\\n        'statusCode': 200,\\n        'body': 'Hello World'\\n    }\\n\"\n        }\n      }\n    }\n  },\n  \"Outputs\": {\n    \"LambdaFunctionArn\": {\n      \"Value\": {\n        \"Fn::GetAtt\": [\n          \"HelloWorldFunction\",\n          \"Arn\"\n        ]\n      },\n      \"Description\": \"ARN of the Lambda function\"\n    }\n  }\n}\n",
#     "test_case": {
#       "task": "Create a JSON CloudFormation template snippet for an AWS Lambda function that executes a simple Hello World function with a basic execution role",
#       "format": "json"
#     },
#     "score": 9.0,
#     "reasoning": "This is a solid, functional CloudFormation template that correctly fulfills the core requirements. The IAM role is properly configured with appropriate trust relationships and permissions, the Lambda function is valid with inline Python code, and outputs are included. However, the solution prioritizes simplicity over production-readiness, with minimal documentation and no defensive programming in the Lambda handler. For the stated task scope ('simple Hello World function'), this is adequate, but falls short of demonstrating best practices for real-world usage."
#   }
# ]
